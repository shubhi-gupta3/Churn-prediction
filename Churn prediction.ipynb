# %% [markdown]
# ## Importing data

# %%
import pandas as pd

# %%
data=pd.read_csv("cell2celltrain.csv")

# %%
data
# Out:
#        CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0         3000002   Yes           24.00           219.0                  22.0
# 1         3000010   Yes           16.99            10.0                  17.0
# 2         3000014    No           38.00             8.0                  38.0
# 3         3000022    No           82.28          1312.0                  75.0
# 4         3000026   Yes           17.14             0.0                  17.0
# 5         3000030    No           38.05           682.0                  52.0
# 6         3000038    No           31.66            26.0                  30.0
# 7         3000042    No           62.13            98.0                  66.0
# 8         3000046    No           35.30            24.0                  35.0
# 9         3000050    No           81.00          1056.0                  75.0
# 10        3000054    No           25.23             2.0                  25.0
# ...

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr())

# %%
gamer = {'Yes': 1,'No': 0} 
data.Churn = [gamer[item] for item in data.Churn]

# %%
data.ChildrenInHH = [gamer[item] for item in data.ChildrenInHH]

# %%
data.HandsetRefurbished = [gamer[item] for item in data.HandsetRefurbished]

# %%
data.HandsetWebCapable = [gamer[item] for item in data.HandsetWebCapable]

# %%
data.TruckOwner = [gamer[item] for item in data.TruckOwner]

# %%
data.RVOwner = [gamer[item] for item in data.RVOwner]

# %%
data.BuysViaMailOrder = [gamer[item] for item in data.BuysViaMailOrder]

# %%
data.RespondsToMailOffers = [gamer[item] for item in data.RespondsToMailOffers]

# %%
data.OptOutMailings = [gamer[item] for item in data.OptOutMailings]

# %%
data.NonUSTravel = [gamer[item] for item in data.NonUSTravel]

# %%
data.OwnsComputer = [gamer[item] for item in data.OwnsComputer]

# %%
data.HasCreditCard = [gamer[item] for item in data.HasCreditCard]

# %%
data.NewCellphoneUser = [gamer[item] for item in data.NewCellphoneUser]

# %%
data.OwnsMotorcycle = [gamer[item] for item in data.OwnsMotorcycle]

# %%
data.MadeCallToRetentionTeam = [gamer[item] for item in data.MadeCallToRetentionTeam]

# %%
data
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 0         3000002      1           24.00           219.0
# 1         3000010      1           16.99            10.0
# 2         3000014      0           38.00             8.0
# 3         3000022      0           82.28          1312.0
# 4         3000026      1           17.14             0.0
# 5         3000030      0           38.05           682.0
# 6         3000038      0           31.66            26.0
# 7         3000042      0           62.13            98.0
# 8         3000046      0           35.30            24.0
# 9         3000050      0           81.00          1056.0
# 10        3000054      0           25.23             2.0
# 11        3000058      0          212.51          1972.0
# 12        3000062      0           42.56           270.0
# 13        3000066      0           63.02           440.0
# 14        3000078      0           50.97           162.0
# ...

# %%
data = data.dropna(how="all")

# %%
data = data[~data.duplicated()]

# %%
data
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 0         3000002      1           24.00           219.0
# 1         3000010      1           16.99            10.0
# 2         3000014      0           38.00             8.0
# 3         3000022      0           82.28          1312.0
# 4         3000026      1           17.14             0.0
# 5         3000030      0           38.05           682.0
# 6         3000038      0           31.66            26.0
# 7         3000042      0           62.13            98.0
# 8         3000046      0           35.30            24.0
# 9         3000050      0           81.00          1056.0
# 10        3000054      0           25.23             2.0
# 11        3000058      0          212.51          1972.0
# 12        3000062      0           42.56           270.0
# 13        3000066      0           63.02           440.0
# 14        3000078      0           50.97           162.0
# ...

# %%
data.NotNewCellphoneUser = [gamer[item] for item in data.NotNewCellphoneUser]

# %%
data = data.drop(["ServiceArea", "Homeownership", "PrizmCode","Occupation","MaritalStatus"], axis=1)

# %%
data
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 0         3000002      1           24.00           219.0
# 1         3000010      1           16.99            10.0
# 2         3000014      0           38.00             8.0
# 3         3000022      0           82.28          1312.0
# 4         3000026      1           17.14             0.0
# 5         3000030      0           38.05           682.0
# 6         3000038      0           31.66            26.0
# 7         3000042      0           62.13            98.0
# 8         3000046      0           35.30            24.0
# 9         3000050      0           81.00          1056.0
# 10        3000054      0           25.23             2.0
# 11        3000058      0          212.51          1972.0
# 12        3000062      0           42.56           270.0
# 13        3000066      0           63.02           440.0
# 14        3000078      0           50.97           162.0
# ...

# %%
gamer = {'1-Highest': 1,'2-High': 2,'3-Good': 3,'4-Medium': 4,'5-Low': 5,'6-VeryLow': 6,'7-Lowest': 7} 
data.CreditRating = [gamer[item] for item in data.CreditRating]

# %%
data
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 0         3000002      1           24.00           219.0
# 1         3000010      1           16.99            10.0
# 2         3000014      0           38.00             8.0
# 3         3000022      0           82.28          1312.0
# 4         3000026      1           17.14             0.0
# 5         3000030      0           38.05           682.0
# 6         3000038      0           31.66            26.0
# 7         3000042      0           62.13            98.0
# 8         3000046      0           35.30            24.0
# 9         3000050      0           81.00          1056.0
# 10        3000054      0           25.23             2.0
# 11        3000058      0          212.51          1972.0
# 12        3000062      0           42.56           270.0
# 13        3000066      0           63.02           440.0
# 14        3000078      0           50.97           162.0
# ...

# %%
data=data.fillna(data.mean())

# %%
data
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 0         3000002      1       24.000000      219.000000
# 1         3000010      1       16.990000       10.000000
# 2         3000014      0       38.000000        8.000000
# 3         3000022      0       82.280000     1312.000000
# 4         3000026      1       17.140000        0.000000
# 5         3000030      0       38.050000      682.000000
# 6         3000038      0       31.660000       26.000000
# 7         3000042      0       62.130000       98.000000
# 8         3000046      0       35.300000       24.000000
# 9         3000050      0       81.000000     1056.000000
# 10        3000054      0       25.230000        2.000000
# 11        3000058      0      212.510000     1972.000000
# 12        3000062      0       42.560000      270.000000
# 13        3000066      0       63.020000      440.000000
# 14        3000078      0       50.970000      162.000000
# ...

# %%
data = data.drop(columns="HandsetPrice")

# %%
data
# Out:
#        CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  \
# 0         3000002      1       24.000000      219.000000
# 1         3000010      1       16.990000       10.000000
# 2         3000014      0       38.000000        8.000000
# 3         3000022      0       82.280000     1312.000000
# 4         3000026      1       17.140000        0.000000
# 5         3000030      0       38.050000      682.000000
# 6         3000038      0       31.660000       26.000000
# 7         3000042      0       62.130000       98.000000
# 8         3000046      0       35.300000       24.000000
# 9         3000050      0       81.000000     1056.000000
# 10        3000054      0       25.230000        2.000000
# 11        3000058      0      212.510000     1972.000000
# 12        3000062      0       42.560000      270.000000
# 13        3000066      0       63.020000      440.000000
# 14        3000078      0       50.970000      162.000000
# ...

# %%
sns.heatmap(data.corr())

# %%
data = data.drop(columns="CustomerID")

# %%
data
# Out:
#        Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0          1       24.000000      219.000000             22.000000
# 1          1       16.990000       10.000000             17.000000
# 2          0       38.000000        8.000000             38.000000
# 3          0       82.280000     1312.000000             75.000000
# 4          1       17.140000        0.000000             17.000000
# 5          0       38.050000      682.000000             52.000000
# 6          0       31.660000       26.000000             30.000000
# 7          0       62.130000       98.000000             66.000000
# 8          0       35.300000       24.000000             35.000000
# 9          0       81.000000     1056.000000             75.000000
# 10         0       25.230000        2.000000             25.000000
# 11         0      212.510000     1972.000000             85.000000
# 12         0       42.560000      270.000000             37.000000
# ...

# %% [markdown]
# ## Decision tree classification

# %%
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier

# %%
X=data.iloc[:,1:13]
X=X.values
y=data.iloc[:,0]
y=y.values
clf = DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6073754836181987

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )
# Out:
# Confusion Matrix :
# [[10387  4200]
#  [ 3817  2015]]
# Accuracy Score : 0.6073754836181987
# Report :
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72     14587
#            1       0.32      0.35      0.33      5832
#
#    micro avg       0.61      0.61      0.61     20419
#    macro avg       0.53      0.53      0.53     20419
# weighted avg       0.62      0.61      0.61     20419

# %% [markdown]
# ## Random forest

# %% [markdown]
# ### n-estimators=100

# %%
from sklearn.ensemble import RandomForestClassifier
random_clf=RandomForestClassifier(n_estimators=100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
random_clf = random_clf.fit(X_train,y_train)
y_pred = random_clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.713355208384348

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )
# Out:
# Confusion Matrix :
# [[14013   524]
#  [ 5329   553]]
# Accuracy Score : 0.713355208384348
# Report :
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.83     14537
#            1       0.51      0.09      0.16      5882
#
#    micro avg       0.71      0.71      0.71     20419
#    macro avg       0.62      0.53      0.49     20419
# weighted avg       0.66      0.71      0.63     20419

# %% [markdown]
# ### n-estimators=1000

# %%
random_clf=RandomForestClassifier(n_estimators=1000)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
random_clf = random_clf.fit(X_train,y_train)
y_pred = random_clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )

# %% [markdown]
# ## Gradient boost

# %% [markdown]
# ### n-estimators=100

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier(n_estimators=100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
gb = gb.fit(X_train,y_train)
y_pred = gb.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )

# %% [markdown]
# ### n-estimators=1000

# %%
gb=GradientBoostingClassifier(n_estimators=1000)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
gb = gb.fit(X_train,y_train)
y_pred = gb.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )

# %% [markdown]
# ## Extreme gradient boost

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
model=model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_estimators=100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
model=model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier(n_estimators=1000)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)
gb = gb.fit(X_train,y_train)
y_pred = gb.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
results = confusion_matrix(y_test, y_pred) 
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred)) 
print ('Report : ')
print (classification_report(y_test, y_pred) )
